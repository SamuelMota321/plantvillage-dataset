# %% [markdown]
# # PlantVillage - Modelo Base EfficientNetB0
#
# Este notebook documenta o fluxo do modelo base: carregamento do dataset, EDA inicial, split estratificado, pipeline `tf.data`, treinamento com transfer learning e avaliaçãoo pós-modelo. A ideia é manter este arquivo como referência reproduzível do primeiro baseline antes de qualquer refinamento.

# %% [markdown]
# ## 1. Imports e configuração
#
# Aqui reunimos as bibliotecas usadas para manipulação de caminhos, visualização, TensorFlow/Keras, split estratificado e métricas de avaliação.

# %%
import os 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
import random 
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from collections import Counter 
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import seaborn as sns

# %% [markdown]
# ## 2. Carregamento dos caminhos e labels
#
# A função percorre a pasta `plantvillage_dataset/color`, assumindo uma estrutura de uma pasta por classe. O resultado são duas listas paralelas: `files` com os caminhos das imagens e `labels` com o nome textual da classe correspondente.

# %%
def load_data(path):
    files = []
    labels = []

    for label in os.listdir(path):
        label_path = os.path.join(path, label)
        if os.path.isdir(label_path):
            for file in os.listdir(label_path):
                files.append(os.path.join(label_path, file))
                labels.append(label)    
    
    return files, labels

# %% [markdown]
# ## 3. Split estratificado
#
# O split preserva a proporção das 38 classes nos conjuntos de treino, validação e teste. A estratégia usada é 80% treino, 10% validação e 10% teste, com `random_state=42` para reprodutibilidade.

# %%
path = os.path.join('plantvillage_dataset/color')
files, labels = load_data(path)

train_files, temp_files, train_labels, temp_labels = train_test_split(
    files,
    labels,
    test_size=0.2,
    random_state=42, 
    stratify=labels
)

val_files, test_files, val_labels, test_labels = train_test_split(
    temp_files, 
    temp_labels,
    test_size=0.5,
    random_state=42, 
    stratify=temp_labels
)

# %% [markdown]
# ## 4. EDA inicial: sanidade dos splits
#
# Esta checagem confirma o número de imagens por conjunto, garante que todas as classes aparecem em todos os splits e mostra o desbalanceamento por classe. Classes pequenas, como `Potato___healthy`, precisam de atenção especial nas métricas.

# %%
print("Total treino:", len(train_files))
print("Total validação:", len(val_files))
print("Total teste:", len(test_files))

print("Classes treino:", len(set(train_labels)))
print("Classes validação:", len(set(val_labels)))
print("Classes teste:", len(set(test_labels)))

print("\nDistribuição treino:")
print(Counter(train_labels))
print("\nDistribuição validação:")
print(Counter(val_labels))
print("\nDistribuição teste:")
print(Counter(test_labels))
# Out:
# Total treino: 43444
# Total validação: 5430
# Total teste: 5431
# Classes treino: 38
# Classes validação: 38
# Classes teste: 38
#
# Distribuição treino:
# ...

# %% [markdown]
# ## 5. EDA visual
#
# Antes de treinar, visualize amostras reais. O objetivo é verificar se imagem e label fazem sentido, se há arquivos corrompidos, imagens fora do domínio ou padrões visuais que possam enviesar o modelo.

# %%
indices = random.sample(range(len(train_files)), 12)

plt.figure(figsize=(14, 8))

for i, idx in enumerate(indices):
    img = Image.open(train_files[idx]).convert("RGB")
    label = train_labels[idx]

    plt.subplot(3, 4, i + 1)
    plt.imshow(img)
    plt.title(label, fontsize=8)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Mapeamento de classes
#
# Redes neurais trabalham com labels numéricos. O mapeamento `class_to_idx` converte o nome textual da classe em inteiro, e `idx_to_class` permite traduzir a predição de volta para o nome original.

# %%
class_names = sorted(set(labels))

class_to_idx = {class_name: idx for idx, class_name in enumerate(class_names)}
idx_to_class = {idx: class_name for class_name, idx in class_to_idx.items()}
num_classes = len(class_names)

print("Número de classes:", len(class_names))
print(class_to_idx)
# Out:
# Número de classes: 38
# ...

# %%
train_label_ids = [class_to_idx[label] for label in train_labels]
val_label_ids = [class_to_idx[label] for label in val_labels]
test_label_ids = [class_to_idx[label] for label in test_labels]

# %% [markdown]
# ## 7. Pipeline TensorFlow
#
# O pipeline lê imagens do disco, decodifica em RGB, redimensiona para 224x224 e entrega batches ao modelo. Para EfficientNetB0 do Keras, as imagens são mantidas em escala `0-255`, pois a família EfficientNet já incorpora o pré-processamento esperado em sua implementação.

# %%
img_size = (224, 224)
batch_size = 16

def load_image(image_path, label_id): 
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, img_size)
    image = tf.cast(image, tf.float32)
   
    return image, label_id

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_files, train_label_ids))
val_ds = tf.data.Dataset.from_tensor_slices((val_files, val_label_ids))
test_ds = tf.data.Dataset.from_tensor_slices((test_files, test_label_ids))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = (
    train_ds
    .shuffle(buffer_size=4096, seed=42)
    .map(load_image, num_parallel_calls=AUTOTUNE)
    .batch(batch_size)
    .prefetch(AUTOTUNE)
)

val_ds = (
    val_ds
    .map(load_image, num_parallel_calls=AUTOTUNE)
    .batch(batch_size)
    .prefetch(AUTOTUNE)
)

test_ds = (
    test_ds
    .map(load_image, num_parallel_calls=AUTOTUNE)
    .batch(batch_size)
    .prefetch(AUTOTUNE)
)

# %% [markdown]
# ## 8. Validação do pipeline
#
# Antes do modelo, confirme se o batch tem o formato esperado: `(batch_size, 224, 224, 3)` e labels numéricos.

# %%
for images, targets in train_ds.take(1):
    print(images.shape)
    print(targets.shape)
    print(targets[:10])
# Out:
# (16, 224, 224, 3)
# (16,)
# tf.Tensor([33 27 19 24 24 19  1  3 13 28], shape=(10,), dtype=int32)

# %%
for images, targets in train_ds.take(1):
    plt.figure(figsize=(12, 8))

    for i in range(12):
        label_id = int(targets[i])
        label_name = idx_to_class[label_id]

        plt.subplot(3, 4, i + 1)
        plt.imshow(images[i].numpy() / 255.0)  
        plt.title(label_name, fontsize=8)
        plt.axis("off")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 9. Modelo base com transfer learning
#
# O baseline usa EfficientNetB0 pré-treinado no ImageNet com o backbone congelado. Nesta etapa, treinamos apenas a cabeça classificadora. Isso reduz custo computacional e cria uma referência forte antes do fine-tuning.

# %%
base_model = EfficientNetB0(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False

inputs = layers.Input(shape=(224, 224, 3))

x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(num_classes, activation="softmax")(x)

model = models.Model(inputs, outputs)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# ### Treinamento inicial do modelo e visualização do resultado

# %%
# EPOCHS = 5

# history = model.fit(
#     train_ds,
#     validation_data=val_ds,
#     epochs=EPOCHS
# )
model = tf.keras.models.load_model("models/efficientnet_b0_baseline.keras")

# %%
val_loss, val_acc = model.evaluate(val_ds)
print(f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.4f}")
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 138s 389ms/step - accuracy: 0.9744 - loss: 0.0784
# Val Loss: 0.0784, Val Accuracy: 0.9744

# %% [markdown]
# ## 10. Avaliação pós-modelo
#
# Acurácia alta é um bom sinal, mas não basta. Como o dataset é desbalanceado, avaliamos `precision`, `recall`, `f1-score`, `macro avg` e erros por classe.

# %%
y_true = []
y_pred = []

for images, labels_batch in val_ds:
    preds = model.predict(images, verbose=0)
    pred_classes = np.argmax(preds, axis=1)

    y_true.extend(labels_batch.numpy())
    y_pred.extend(pred_classes)

print(classification_report(
    y_true,
    y_pred,
    target_names=class_names,
    digits=4
))
# Out:
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab     0.9672    0.9365    0.9516        63
#                                  Apple___Black_rot     0.9683    0.9839    0.9760        62
#                           Apple___Cedar_apple_rust     0.9655    1.0000    0.9825        28
#                                    Apple___healthy     0.9877    0.9817    0.9847       164
#                                Blueberry___healthy     1.0000    1.0000    1.0000       150
#           Cherry_(including_sour)___Powdery_mildew     1.0000    0.9905    0.9952       105
#                  Cherry_(including_sour)___healthy     1.0000    1.0000    1.0000        86
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot     0.9318    0.7885    0.8542        52
#                        Corn_(maize)___Common_rust_     1.0000    1.0000    1.0000       119
# ...

# %%
cm = confusion_matrix(y_true, y_pred)

n_classes = len(class_names)
mid = n_classes // 2

fig, axes = plt.subplots(1, 2, figsize=(24, 10))

splits = [
    (0, mid, "Primeira Parte das Classes"),
    (mid, n_classes, "Segunda Parte das Classes")
]

for i, (start, end, title) in enumerate(splits):
    subset_cm = cm[start:end, start:end]
    subset_names = class_names[start:end]
    
    sns.heatmap(
        subset_cm,
        ax=axes[i],
        xticklabels=subset_names,
        yticklabels=subset_names,
        cmap="Blues",
        fmt="d",
        annot=True, 
        cbar=False
    )
    axes[i].set_title(f"Matriz de Confusão - {title}")
    axes[i].set_xlabel("Predito")
    axes[i].set_ylabel("Real")
    axes[i].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
errors = []

for images, labels_batch in val_ds:
    preds = model.predict(images, verbose=0)
    pred_classes = np.argmax(preds, axis=1)

    for i in range(len(labels_batch)):
        true_id = int(labels_batch[i])
        pred_id = int(pred_classes[i])

        if true_id != pred_id:
            confidence = float(np.max(preds[i]))
            errors.append((images[i].numpy(), true_id, pred_id, confidence))

print("Total de erros:", len(errors))
# Out:
# Total de erros: 139

# %%
plt.figure(figsize=(14, 10))

for i, (img, true_id, pred_id, conf) in enumerate(errors[:12]):
    plt.subplot(3, 4, i + 1)
    plt.imshow(img.astype("uint8"))
    plt.title(
        f"Real: {idx_to_class[true_id]}\nPred: {idx_to_class[pred_id]}\nConf: {conf:.2f}",
        fontsize=8
    )
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_ds)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 135s 396ms/step - accuracy: 0.9740 - loss: 0.0872
# Test Loss: 0.0872
# Test Accuracy: 0.9740

# %% [markdown]
# ## 11. Salvamento do baseline
#
# Salve o modelo base antes de qualquer refinamento. Isso permite comparar baseline e fine-tuned de forma justa e voltar ao ponto anterior caso o refinamento piore alguma classe.

# %%
# model.save("models/efficientnet_b0_baseline.keras")
